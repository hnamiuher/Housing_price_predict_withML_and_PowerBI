# %%
# đọc dữ liệu các file 
# list_ma_tin
with open('F:\Thống Kê Máy Tính\Crawl_Data/file_txt\list_Matin1.txt', 'r', encoding='utf-8') as f:
    list_ma_tin = f.read().splitlines()

# list_loaiBDS
with open('F:\Thống Kê Máy Tính\Crawl_Data/file_txt\list_loaiBDS1.txt', 'r', encoding='utf-8') as f:
    list_loaiBDS = f.read().splitlines()

#list_khu_vuc
with open('F:\Thống Kê Máy Tính\Crawl_Data/file_txt/vung2.txt', 'r', encoding='utf-8') as f:
    list_vung = f.read().splitlines()

# list_dia_chi
with open('F:\Thống Kê Máy Tính\Crawl_Data/file_txt\list_dia_chi1.txt', 'r', encoding='utf-8') as f:
    list_dia_chi = f.read().splitlines()

# list_dien_tich
with open('F:\Thống Kê Máy Tính\Crawl_Data/file_txt\list_dien_tich2.txt', 'r', encoding='utf-8') as f:
    list_dien_tich = f.read().splitlines()

# list_phap_ly
with open('F:\Thống Kê Máy Tính\Crawl_Data/file_txt\list_phap_ly2.txt', 'r', encoding='utf-8') as f:
    list_phap_ly = f.read().splitlines()

# list_gia
with open('F:\Thống Kê Máy Tính\Crawl_Data/file_txt\list_price2.txt', 'r', encoding='utf-8') as f:
    list_gia = f.read().splitlines()

# list_lo_gioi
with open('F:\Thống Kê Máy Tính\Crawl_Data/file_txt\list_lo_gioi2.txt', 'r', encoding='utf-8') as f:
    list_lo_gioi = f.read().splitlines()

# list_so_lau
with open('F:\Thống Kê Máy Tính\Crawl_Data/file_txt\list_so_lau2.txt', 'r', encoding='utf-8') as f:
    list_so_lau = f.read().splitlines()

# list_so_phong_ngu
with open('F:\Thống Kê Máy Tính\Crawl_Data/file_txt\list_so_phong_ngu2.txt', 'r', encoding='utf-8') as f:
    list_so_phong_ngu = f.read().splitlines()

# list_sdt_LH
with open('F:\Thống Kê Máy Tính\Crawl_Data/file_txt\list_sdt_LH1.txt', 'r', encoding='utf-8') as f:
    list_sdt_LH = f.read().splitlines()

# list_link_truy_cap
with open('F:\Thống Kê Máy Tính\Crawl_Data/file_txt\link_post1.txt', 'r', encoding='utf-8') as f:
    list_post = f.read().splitlines()

# %%
len(list_ma_tin), len(list_loaiBDS), len(list_vung), len(list_dia_chi), len(list_dien_tich), len(list_phap_ly), len(list_gia), len(list_lo_gioi), len(list_so_lau), len(list_so_phong_ngu), len(list_sdt_LH), len(list_post)
# Out:
# (5400, 5400, 5400, 5400, 5400, 5400, 5400, 5400, 5400, 5400, 5400, 5400)

# %%
import pandas as pd
# tạo dataframe từ các list trên, dạng link thì có thể truy cập được
df = pd.DataFrame({'Mã tin': list_ma_tin, 'Loại BĐS': list_loaiBDS, 'Khu vực': list_vung, 'Địa chỉ': list_dia_chi, 'Diện tích (m2)': list_dien_tich, 'Pháp lý': list_phap_ly, 'Giá (tỷ)': list_gia, 'Lộ giới (m)': list_lo_gioi, 'Số lầu': list_so_lau, 'Số phòng ngủ': list_so_phong_ngu, 'Số điện thoại liên hệ': list_sdt_LH, 'Link truy cập': list_post})

# %%
df
# Out:
#        Mã tin         Loại BĐS      Khu vực  \
# 0     3500611     Nhà ngõ, hẻm  Hồ Chí Minh
# 1     4659719              Đất       Hà Nội
# 2     4813510         Biệt thự       Hà Nội
# 3     4822936     Nhà mặt tiền       Hà Nội
# 4     4659316     Nhà ngõ, hẻm  Hồ Chí Minh
# ...       ...              ...          ...
# 5395  4631062     Nhà mặt tiền       Hà Nội
# 5396  4783042         Biệt thự       Hà Nội
# 5397  4741030     Nhà ngõ, hẻm       Hà Nội
# 5398  4788221  Căn hộ chung cư       Hà Nội
# 5399  4420632     Nhà mặt tiền       Hà Nội
#
#                                                 Địa chỉ Diện tích (m2)  \
# 0      Đường Nguyễn Ánh Thủ, Phường Trung Mỹ Tây, Qu...           80.0
# 1      Đường Long Khánh, Thị trấn Trạm Trôi, Huyện H...           75.0
# 2                 Phường Văn Quán, Quận Hà Đông, Hà Nội           50.0
# 3      Đường Ao Sen, Phường Mộ Lao, Quận Hà Đông, Hà...           50.0
# 4      Đường Nguyễn Văn Lượng, Phường 10, Quận Gò Vấ...           55.0
# ...

# %%
# viết dataframe vào file csv
df.to_csv('F:\Thống Kê Máy Tính\Crawl_Data\Data_BDS_hoanchinh.csv', index=False, encoding='utf-8-sig')

# %%
# đọc file csv
import pandas as pd
df = pd.read_csv('F:\Thống Kê Máy Tính\Crawl_Data\Data_BDS_hoanchinh.csv', encoding='utf-8-sig')
df
# Out:
#        Mã tin         Loại BĐS      Khu vực  \
# 0     3500611     Nhà ngõ, hẻm  Hồ Chí Minh
# 1     4659719              Đất       Hà Nội
# 2     4813510         Biệt thự       Hà Nội
# 3     4822936     Nhà mặt tiền       Hà Nội
# 4     4659316     Nhà ngõ, hẻm  Hồ Chí Minh
# ...       ...              ...          ...
# 1915  4631062     Nhà mặt tiền       Hà Nội
# 1916  4783042         Biệt thự       Hà Nội
# 1917  4741030     Nhà ngõ, hẻm       Hà Nội
# 1918  4788221  Căn hộ chung cư       Hà Nội
# 1919  4420632     Nhà mặt tiền       Hà Nội
#
#                                                 Địa chỉ  Diện tích (m2)  \
# 0      Đường Nguyễn Ánh Thủ, Phường Trung Mỹ Tây, Qu...            80.0
# 1      Đường Long Khánh, Thị trấn Trạm Trôi, Huyện H...            75.0
# 2                 Phường Văn Quán, Quận Hà Đông, Hà Nội            50.0
# 3      Đường Ao Sen, Phường Mộ Lao, Quận Hà Đông, Hà...            50.0
# ...

# %%
# ghi cột thứ 3 vào file txt
with open('F:\Thống Kê Máy Tính\Crawl_Data/file_txt\list_dia_chi2.txt', 'w', encoding='utf-8') as f:
    for i in df['Địa chỉ']:
        f.write(i + '\n')
