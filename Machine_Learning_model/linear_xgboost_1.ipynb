# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv('Data_BDS_hoanchinh.csv',sep=',')
df.head()
# Out:
#     Mã tin      Loại BĐS      Khu vực  \
# 0  3500611  Nhà ngõ, hẻm  Hồ Chí Minh
# 1  4659719           Đất       Hà Nội
# 2  4813510      Biệt thự       Hà Nội
# 3  4822936  Nhà mặt tiền       Hà Nội
# 4  4659316  Nhà ngõ, hẻm  Hồ Chí Minh
#
#                                              Địa chỉ  Diện tích (m2)  \
# 0   Đường Nguyễn Ánh Thủ, Phường Trung Mỹ Tây, Qu...            80.0
# 1   Đường Long Khánh, Thị trấn Trạm Trôi, Huyện H...            75.0
# 2              Phường Văn Quán, Quận Hà Đông, Hà Nội            50.0
# 3   Đường Ao Sen, Phường Mộ Lao, Quận Hà Đông, Hà...            50.0
# 4   Đường Nguyễn Văn Lượng, Phường 10, Quận Gò Vấ...            55.0
#
#           Pháp lý  Giá (tỷ)  Lộ giới (m)  Số lầu  Số phòng ngủ  \
# 0  Sổ hồng/ Sổ đỏ      6.99          6.0       3             4
# 1  Sổ hồng/ Sổ đỏ      4.20          5.0       0             0
# 2  Sổ hồng/ Sổ đỏ     12.50          4.0       7             4
# ...

# %%
df.shape
# Out:
# (1920, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1920 entries, 0 to 1919
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Mã tin                 1920 non-null   int64
#  1   Loại BĐS               1920 non-null   object
#  2   Khu vực                1920 non-null   object
#  3   Địa chỉ                1920 non-null   object
#  4   Diện tích (m2)         1920 non-null   float64
#  5   Pháp lý                1920 non-null   object
#  6   Giá (tỷ)               1920 non-null   float64
#  7   Lộ giới (m)            1920 non-null   float64
#  8   Số lầu                 1920 non-null   int64
#  9   Số phòng ngủ           1920 non-null   int64
#  10  Số điện thoại liên hệ  1920 non-null   object
#  11  Link truy cập          1920 non-null   object
# dtypes: float64(3), int64(3), object(6)
# memory usage: 180.1+ KB

# %%
# col_drop = ['Mã tin','Tên','SĐT','Địa chỉ','Link','Khu vực.1']
# df = df.drop(col_drop, axis=1)
col_drop = ['Mã tin','Địa chỉ','Link truy cập','Số điện thoại liên hệ']
df = df.drop(col_drop, axis=1)

# %%
df.head()
# Out:
#        Loại BĐS      Khu vực  Diện tích (m2)         Pháp lý  Giá (tỷ)  \
# 0  Nhà ngõ, hẻm  Hồ Chí Minh            80.0  Sổ hồng/ Sổ đỏ      6.99
# 1           Đất       Hà Nội            75.0  Sổ hồng/ Sổ đỏ      4.20
# 2      Biệt thự       Hà Nội            50.0  Sổ hồng/ Sổ đỏ     12.50
# 3  Nhà mặt tiền       Hà Nội            50.0  Sổ hồng/ Sổ đỏ      7.20
# 4  Nhà ngõ, hẻm  Hồ Chí Minh            55.0  Sổ hồng/ Sổ đỏ      5.25
#
#    Lộ giới (m)  Số lầu  Số phòng ngủ
# 0          6.0       3             4
# 1          5.0       0             0
# 2          4.0       7             4
# 3          4.0       6            10
# 4          6.0       1             2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1920 entries, 0 to 1919
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Loại BĐS        1920 non-null   object
#  1   Khu vực         1920 non-null   object
#  2   Diện tích (m2)  1920 non-null   float64
#  3   Pháp lý         1920 non-null   object
#  4   Giá (tỷ)        1920 non-null   float64
#  5   Lộ giới (m)     1920 non-null   float64
#  6   Số lầu          1920 non-null   int64
#  7   Số phòng ngủ    1920 non-null   int64
# dtypes: float64(3), int64(2), object(3)
# memory usage: 120.1+ KB

# %%
df.describe()
# Out:
#        Diện tích (m2)     Giá (tỷ)  Lộ giới (m)       Số lầu  Số phòng ngủ
# count     1920.000000  1920.000000  1920.000000  1920.000000   1920.000000
# mean       259.841667    24.005839     9.695573     3.316146      4.813542
# std       1703.411179    47.266261    10.449831     3.492499      7.738538
# min          3.000000     0.003000     0.000000     0.000000      0.000000
# 25%         50.000000     4.500000     2.500000     0.000000      0.000000
# 50%         72.000000     7.900000     5.000000     3.000000      4.000000
# 75%        125.000000    24.500000    15.000000     5.000000      5.000000
# max      40000.000000   600.000000    60.000000    85.000000    100.000000

# %%
df.isna().sum()
# Out:
# Loại BĐS          0
# Khu vực           0
# Diện tích (m2)    0
# Pháp lý           0
# Giá (tỷ)          0
# Lộ giới (m)       0
# Số lầu            0
# Số phòng ngủ      0
# dtype: int64

# %%
df['Loại BĐS'].value_counts()
# Out:
# Nhà ngõ, hẻm            830
# Nhà mặt tiền            652
# Đất                     195
# Biệt thự                 94
# Nhà hàng, khách sạn      41
# Căn hộ chung cư          31
# Văn phòng                29
# Phòng trọ, nhà trọ       20
# Đất nền, phân lô         12
# Đất nông, lâm nghiệp      6
# Kho, xưởng                5
# Mặt bằng                  3
# Các loại khác             2
# Name: Loại BĐS, dtype: int64

# %%
df['Pháp lý'].replace('0', 'Không xác định', inplace=True)
df['Pháp lý'].value_counts()
# Out:
# Sổ hồng/ Sổ đỏ    1674
# Chưa Xác Định      223
# Giấy tờ hợp lệ      22
# Giấy phép XD         1
# Name: Pháp lý, dtype: int64

# %%
df.head()
# Out:
#        Loại BĐS      Khu vực  Diện tích (m2)         Pháp lý  Giá (tỷ)  \
# 0  Nhà ngõ, hẻm  Hồ Chí Minh            80.0  Sổ hồng/ Sổ đỏ      6.99
# 1           Đất       Hà Nội            75.0  Sổ hồng/ Sổ đỏ      4.20
# 2      Biệt thự       Hà Nội            50.0  Sổ hồng/ Sổ đỏ     12.50
# 3  Nhà mặt tiền       Hà Nội            50.0  Sổ hồng/ Sổ đỏ      7.20
# 4  Nhà ngõ, hẻm  Hồ Chí Minh            55.0  Sổ hồng/ Sổ đỏ      5.25
#
#    Lộ giới (m)  Số lầu  Số phòng ngủ
# 0          6.0       3             4
# 1          5.0       0             0
# 2          4.0       7             4
# 3          4.0       6            10
# 4          6.0       1             2

# %%
df_filters = df['Khu vực'].value_counts()
df_filters = df_filters[df_filters > 300]
df_filters
# Out:
# Hà Nội         1309
# Hồ Chí Minh     360
# Name: Khu vực, dtype: int64

# %%
df = df[df['Khu vực'].isin(df_filters.index)]
df.head()
# Out:
#        Loại BĐS      Khu vực  Diện tích (m2)         Pháp lý  Giá (tỷ)  \
# 0  Nhà ngõ, hẻm  Hồ Chí Minh            80.0  Sổ hồng/ Sổ đỏ      6.99
# 1           Đất       Hà Nội            75.0  Sổ hồng/ Sổ đỏ      4.20
# 2      Biệt thự       Hà Nội            50.0  Sổ hồng/ Sổ đỏ     12.50
# 3  Nhà mặt tiền       Hà Nội            50.0  Sổ hồng/ Sổ đỏ      7.20
# 4  Nhà ngõ, hẻm  Hồ Chí Minh            55.0  Sổ hồng/ Sổ đỏ      5.25
#
#    Lộ giới (m)  Số lầu  Số phòng ngủ
# 0          6.0       3             4
# 1          5.0       0             0
# 2          4.0       7             4
# 3          4.0       6            10
# 4          6.0       1             2

# %%
for col in df.columns:
    if df[col].dtype == 'object':
        df[col] = df[col].astype('category').cat.codes

df.head()
# Out:
#    Loại BĐS  Khu vực  Diện tích (m2)  Pháp lý  Giá (tỷ)  Lộ giới (m)  Số lầu  \
# 0         6        1            80.0        3      6.99          6.0       3
# 1         9        0            75.0        3      4.20          5.0       0
# 2         0        0            50.0        3     12.50          4.0       7
# 3         5        0            50.0        3      7.20          4.0       6
# 4         6        1            55.0        3      5.25          6.0       1
#
#    Số phòng ngủ
# 0             4
# 1             0
# 2             4
# 3            10
# 4             2

# %%
sns.scatterplot(x='Giá (tỷ)', y='Diện tích (m2)', data=df)
plt.show()

# %%
# remove outliers
# df = df[df['Giá (tỷ)'] < 70]
# df = df[df['Diện tích (m2)'] < 600]
df = df[df['Giá (tỷ)'] < 250]
df = df[df['Diện tích (m2)'] < 300]

# %%
sns.scatterplot(x='Giá (tỷ)', y='Diện tích (m2)', data=df)
plt.show()

# %%
sns.scatterplot(x='Giá (tỷ)', y='Số lầu', data=df)
plt.show()

# %%
df = df[df['Số lầu'] < 20]
df = df[df['Giá (tỷ)'] < 200]

# %%
sns.scatterplot(x='Giá (tỷ)', y='Số lầu', data=df)
plt.show()

# %%
sns.scatterplot(x='Giá (tỷ)', y='Số phòng ngủ', data=df)
plt.show()

# %%
df = df[df['Số phòng ngủ'] < 20]
df = df[df['Giá (tỷ)'] < 125]

# %%
sns.scatterplot(x='Giá (tỷ)', y='Số phòng ngủ', data=df)
plt.show()

# %%
sns.scatterplot(x='Giá (tỷ)', y='Lộ giới (m)', data=df)
plt.show()

# %%
df = df[df['Lộ giới (m)'] < 35]

# %%
sns.scatterplot(x='Giá (tỷ)', y='Lộ giới (m)', data=df)
plt.show()

# %%
sns.pairplot(df)
plt.show()

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.preprocessing import StandardScaler

X = df.drop('Giá (tỷ)', axis=1)
y = df['Giá (tỷ)']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=1)

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

model = LinearRegression()
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

score = r2_score(y_test, y_pred)

# %%
print(f'R2 score: {score:.2}')
# Out:
# R2 score: 0.54

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1493 entries, 0 to 1919
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Loại BĐS        1493 non-null   int8
#  1   Khu vực         1493 non-null   int8
#  2   Diện tích (m2)  1493 non-null   float64
#  3   Pháp lý         1493 non-null   int8
#  4   Giá (tỷ)        1493 non-null   float64
#  5   Lộ giới (m)     1493 non-null   float64
#  6   Số lầu          1493 non-null   int64
#  7   Số phòng ngủ    1493 non-null   int64
# dtypes: float64(3), int64(2), int8(3)
# memory usage: 74.4 KB

# %%
from sklearn.model_selection import KFold, cross_val_score
import xgboost as xgb

model = xgb.XGBRegressor()
kfold = KFold(n_splits=10, random_state=1, shuffle=True)

X = df.drop('Giá (tỷ)', axis=1)
y = df['Giá (tỷ)']
r2 = []
for train_index, test_index in kfold.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]    
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    r2.append(r2_score(y_test, y_pred))

np.mean(r2)
# Out:
# 0.5765533789072961

# %%
sns.boxplot(df)
# Out:
# <AxesSubplot:>

# %%
ax = sns.regplot(x=y_pred, y=y_test, color='blue') 

ax.lines[0].set_color('red')

ax.set(xlabel='Giá dự đoán', ylabel='Giá thực tế')
plt.show("Giá thực tế")
